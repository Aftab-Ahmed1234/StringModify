# %%
a="aftab ahmed"
print(a.upper())
# Out:
# AFTAB AHMED

# %%
a="AFTAB AHMED"
print(a.lower())
# Out:
# aftab ahmed

# %%
a="            Aftab Ahmed"
print(a.strip())
# Out:
# Aftab Ahmed

# %%
a="AAftab Ahmed"
print(a.replace("AAftab","Aftab"))
# Out:
# Aftab Ahmed

# %%
a="Aftab, Ahmed, Bhan"
print(a.split(","))
# Out:
# ['Aftab', ' Ahmed', ' Bhan']
