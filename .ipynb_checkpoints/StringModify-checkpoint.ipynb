# %%
a="aftab ahmed"
print(a.upper())
# Out:
# AFTAB AHMED

# %%
a="AFTAB AHMED"
print(a.lower())
# Out:
# aftab ahmed

# %%
a="Aftab,       Ahmed"
print(a.strip)
# Out:
# <built-in method strip of str object at 0x0000029FE19C2150>
